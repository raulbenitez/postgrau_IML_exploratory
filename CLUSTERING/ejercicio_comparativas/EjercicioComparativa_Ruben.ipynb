# %%
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
import numpy as np
n_samples = 2500
centers = [(12, 5), (10,10),(5,15)]
random_state = 170
X, y = make_blobs(n_samples=n_samples, centers=centers,random_state=random_state)
X_filtered = np.vstack((X[y == 0][:70], X[y == 1][:100], X[y == 2][:10]))

X_kmeans = KMeans(n_clusters=3).fit_predict(X_filtered)

X_agglomer=AgglomerativeClustering(n_clusters=3).fit_predict(X_filtered) 


plt.figure(figsize=(12, 12))
plt.subplot(221)
plt.scatter(X_filtered[:, 0], X_filtered[:, 1])
plt.title("Clústers con diferente numero de observaciones")

plt.subplot(222)
plt.scatter(X_filtered[:, 0], X_filtered[:, 1],c=X_kmeans)
plt.title("Clústers con diferente numero de observaciones Kmeans")


plt.figure(figsize=(12, 12))
plt.subplot(223)
plt.scatter(X_filtered[:, 0], X_filtered[:, 1],c=X_agglomer)
plt.title("Clústers con diferente numero de observaciones Agglomerative")
plt.show()
