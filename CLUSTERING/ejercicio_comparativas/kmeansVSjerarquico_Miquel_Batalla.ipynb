# %% [markdown]
# <a href="https://colab.research.google.com/github/raulbenitez/postgrau_IML_exploratory/blob/master/CLUSTERING/ejercicio_comparativas/kmeansVSjerarquico_Miquel_Batalla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Blobs con diferente numero de observaciones

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering

n_samples = 500
centers = [(0, 0), (7.5,7.5),(10,10)]
random_state = 170

# Clusteres normales:
X, y = make_blobs(n_samples=n_samples, centers=centers,random_state=random_state)

# Unevenly sized blobs
X_filtered = np.vstack((X[y == 0][:500], X[y == 1][:100], X[y == 2][:10]))

plt.figure(figsize=(5, 5))
plt.scatter(X_filtered[:, 0], X_filtered[:, 1])
plt.title("Clústers con diferente numero de observaciones")
plt.show()

# %%
plt.figure(figsize=(15,7))

y_pred = KMeans(n_clusters=3,
                random_state=random_state).fit_predict(X_filtered)
plt.subplot(121)
plt.scatter(X_filtered[:, 0], X_filtered[:, 1], c=y_pred)
plt.title("Kmeans clustering")

plt.subplot(122)
clustering = AgglomerativeClustering(n_clusters=3).fit(X_filtered) 
labels = clustering.fit_predict(X_filtered)
plt.scatter(X_filtered[:, 0], X_filtered[:, 1], c=labels)
plt.title("Agglomerative clustering")
plt.show()
