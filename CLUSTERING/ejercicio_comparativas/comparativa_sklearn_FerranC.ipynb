# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering
from sklearn import mixture

random_state = 170

# Generate data:
n_samples = 1500
centers = [(0, 0), (6, 6), (12,12)]
X, y = make_blobs(n_samples=n_samples, centers=centers, n_features=3,random_state=0)
transformation1 = [[0.60834549, -0.63667341], [-0.40887718, 0.85253229]]
X_aniso = np.dot(X, transformation)

# %%
# Kmeans clustering:
# Incorrect number of clusters
clust_kmeans = KMeans(n_clusters=3, random_state=random_state).fit_predict(X_aniso)

# Agglomerative clustering:
clust_agg = AgglomerativeClustering(n_clusters=3).fit_predict(X_aniso) 


# GMM clustering:
clust_gmm = mixture.GaussianMixture(n_components=3,covariance_type='full').fit_predict(X_aniso)

plt.figure(figsize=(14,7))

ax0 = plt.subplot(1,3,1)
plt.scatter(X_aniso[:, 0], X_aniso[:, 1], c=clust_kmeans)
plt.title("Kmeans clustering")

ax1 = plt.subplot(1,3,2)
plt.scatter(X_aniso[:, 0], X_aniso[:, 1], c=clust_gmm)
plt.title("GMM clustering")

ax2 = plt.subplot(1,3,3)
plt.scatter(X_aniso[:, 0], X_aniso[:, 1], c=clust_agg)
plt.title("Agglomerative clustering")
plt.show()

# %% [markdown]
# Se tiene que separar un poco los centros de las blobs. Si no salen los 3 mal. Cuando separas se ve que GMM es mejor.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering
from sklearn import mixture

random_state = 170

# Generate data:
n_samples = 1500
centers1 = [(0, 0), (7, 7)]
X1, y1 = make_blobs(n_samples=n_samples, centers=centers1, n_features=2,random_state=0)
transformation1 = [[0.60834549, -0.63667341], [-0.40887718, 0.85253229]]
X_aniso1 = np.dot(X1, transformation)

centers2 = [(0, 0)]
X2, y2 = make_blobs(n_samples=n_samples, centers=centers2, n_features=1,random_state=0)
transformation2 = [ [-0.40887718, -0.85253229], [-0.60834549, -0.63667341]]
X_aniso2 = np.dot(X2, transformation2)

fig = plt.figure(figsize=(8,8))
plt.scatter(X_aniso1[:, 0], X_aniso1[:, 1], c='r')
plt.scatter(X_aniso2[:, 0], X_aniso2[:, 1], c='g')

plt.show()

# %%
import numpy as np
X_aniso_total = np.append(X_aniso1,X_aniso2,axis=0)
fig = plt.figure(figsize=(8,8))
plt.scatter(X_aniso_total[:, 0], X_aniso_total[:, 1])

plt.show()

# %%
X_aniso_total.shape
# Out:
# (3000, 2)

# %%
# Kmeans clustering:
# Incorrect number of clusters
clust_kmeans_x = KMeans(n_clusters=3, random_state=random_state).fit_predict(X_aniso_total)

# Agglomerative clustering:
clust_agg_x = AgglomerativeClustering(n_clusters=3).fit_predict(X_aniso_total)


# GMM clustering:
clust_gmm_x = mixture.GaussianMixture(n_components=3,covariance_type='full').fit_predict(X_aniso_total)

plt.figure(figsize=(14,7))

ax0 = plt.subplot(1,3,1)
plt.scatter(X_aniso_total[:, 0], X_aniso_total[:, 1], c=clust_kmeans_x)
plt.title("Kmeans clustering")

ax1 = plt.subplot(1,3,2)
plt.scatter(X_aniso_total[:, 0], X_aniso_total[:, 1], c=clust_gmm_x)
plt.title("GMM clustering")

ax2 = plt.subplot(1,3,3)
plt.scatter(X_aniso_total[:, 0], X_aniso_total[:, 1], c=clust_agg_x)
plt.title("Agglomerative clustering")
plt.show()
