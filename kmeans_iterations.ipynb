# %% [markdown]
# <a href="https://colab.research.google.com/github/raulbenitez/postgrau_IML_exploratory/blob/master/kmeans_iterations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs


n_samples = 1500
centers = [(1, -1), (5, 5), (10,10)]
X, y = make_blobs(n_samples=n_samples, centers=centers, n_features=2,random_state=0)

# %%
fig = plt.figure(figsize=(7,7))
ax = plt.gca()
ax.scatter(X[:, 0], X[:, 1], c=labels)

clustering = KMeans(n_clusters=3,random_state=12,init='random',n_init=1,algorithm='full').fit(X) 

for i in range(clustering.n_iter_):
  clustering1 = KMeans(n_clusters=3,max_iter=i+1,random_state=12,init='random',n_init=1,algorithm='full').fit(X) 
  ax.scatter(clustering1.cluster_centers_[0,0],clustering1.cluster_centers_[0,1],c='r',marker='x')
  ax.scatter(clustering1.cluster_centers_[1,0],clustering1.cluster_centers_[1,1],c='g',marker='x')
  ax.scatter(clustering1.cluster_centers_[2,0],clustering1.cluster_centers_[2,1],c='b',marker='x')

  print('centers in iteration {} are {}'.format(i+1,clustering1.cluster_centers_))

plt.show()
# Out:
# centers in iteration 1 are [[ 0.47812751 -0.29805553]
#  [ 7.48221527  7.49808436]
#  [ 1.3451938  -1.62632888]]
# centers in iteration 2 are [[ 0.62635401 -0.10413675]
#  [ 7.53101394  7.54391192]
#  [ 1.3459005  -1.62954427]]
# centers in iteration 3 are [[ 0.89792623  0.17187139]
#  [ 7.56973847  7.58847303]
#  [ 1.21240056 -1.6614857 ]]
# centers in iteration 4 are [[ 1.36027869  0.64638404]
#  [ 7.63543001  7.66483063]
#  [ 1.03619403 -1.63194048]]
# centers in iteration 5 are [[ 2.23583383  1.63886334]
#  [ 7.78512975  7.8182786 ]
#  [ 0.88089871 -1.47054357]]
# centers in iteration 6 are [[ 3.78987472  3.55051017]
#  [ 8.27251204  8.31158449]
#  [ 0.86525252 -1.22207102]]
# centers in iteration 7 are [[ 4.92580711  4.91279634]
#  [ 9.697056    9.74227314]
#  [ 0.93353916 -1.03072789]]
# centers in iteration 8 are [[ 5.02189272  5.00534116]
#  [ 9.9227622   9.97478067]
#  [ 0.93463431 -1.02514773]]
# centers in iteration 9 are [[ 5.02189272  5.00534116]
# ...
