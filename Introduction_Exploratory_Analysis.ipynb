# %% [markdown]
# # Part I: Exploratory Analysis of multidimensional data
#
# This first section is devoted to:
#
# * Reading, loading and importing data
#
# * Visualization of multidimensional data
#
# * Dimensionality reduction using PCA

# %% [markdown]
# ## a) Reading, loading and importing data

# %% [markdown]
# ### Reading data from a txt file using pandas:

# %%
import pandas as pd
data = pd.read_csv('signal.txt', sep="\t", header=None)
data.head(10) # print first 10 lines of the data
# Out:
#            0
# 0  346.69891
# 1  346.55242
# 2  346.14999
# 3  353.30562
# 4  361.57537
# 5  369.12295
# 6  376.19024
# 7  374.84792
# 8  371.51876
# 9  368.58175

# %% [markdown]
# ### Import from UCI datasets: Download dataset from the UCI website:

# %%
diris = pd.read_csv('iris.data',header=-1)
diris.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %% [markdown]
# ### Convert pandas dataframe to numpy array:

# %%
import numpy as np 
x = np.array(diris)
x[0:5,:]
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'Iris-setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'Iris-setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'Iris-setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'Iris-setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'Iris-setosa']], dtype=object)

# %% [markdown]
# ### Import data from built-in datasets in different libraries:

# %% [markdown]
# Seaborn libraries: Will provide a pandas dataframe:
#
# Iris from seaborn:

# %%
import seaborn as sns; sns.set(style="ticks", color_codes=True)
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [raw]
# Titanic dataset:

# %%
dtitanic = sns.load_dataset('titanic')
dtitanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# Cars dataset:

# %%
dcars = sns.load_dataset("mpg")
dcars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# ### Importing images:

# %% [markdown]
# From an image file:

# %%
import skimage as sk # load skimage libraries
I = sk.io.imread('image1.tif') # read image using imread function
sk.io.imshow(I) # visualize image using imshow function
sk.io.show()

# %% [markdown]
# From a built-in image dataset:

# %%
import skimage as sk # load skimage libraries
from skimage import io
IC = sk.data.astronaut() # load a color image from the skimage built-in dataset
sk.io.imshow(IC) # visualize image using imshow function
sk.io.show()

# %% [markdown]
# ### Generating synthetic random data:

# %% [markdown]
# Generate 1000 observations following a Normal distribution

# %%
N = 1000
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, N)
s
# Out:
# array([ 1.20289740e-01, -2.50043508e-02, -1.94347094e-02, -9.91229177e-02,
#         4.03367579e-02, -3.29661039e-02, -1.72414777e-02, -1.59935482e-01,
#         1.01000664e-01,  1.67224056e-01,  1.19631304e-02, -1.47910174e-02,
#         4.03054196e-03,  5.91371368e-02,  3.51899413e-02,  2.77292237e-02,
#         3.63777431e-02,  4.15962635e-02,  1.05694628e-01,  6.73718892e-02,
#        -8.17180814e-02,  7.21364709e-02,  5.82511644e-03, -1.43373088e-02,
#        -5.47883840e-02, -1.16173669e-01,  4.11869877e-02, -6.70074543e-02,
#         6.06776693e-02, -1.36414010e-01, -6.20183706e-02, -3.61825210e-02,
#         6.00297680e-02,  1.48374579e-01,  5.91021913e-02, -6.38505557e-02,
#        -5.10918459e-02,  2.49938774e-02, -7.61884382e-02, -3.76976334e-03,
#        -7.43434773e-02, -1.18966844e-01, -1.09856239e-01,  7.99142441e-02,
#        -4.25754983e-02,  2.02320638e-01,  2.31580803e-01,  7.12726342e-02,
# ...

# %% [markdown]
# Multivariate normal observations in 2D

# %%
N=1000
mean1 = [5, -5]
cov1 = [[1, 5], [5, 100]]  
# multivariate normal
v = np.random.multivariate_normal(mean1, cov1, N)

# %% [markdown]
# ## b) Visualization of data:
#
# We are going to use basically two graphical libraries: matplotlib (when data is numpy array) and seaborn (when data is a pandas dataframe).

# %% [markdown]
# ### Basic plots: scatter, plot, histograms

# %% [markdown]
# Represent the time signal we loaded from a txt file before:

# %%
fig = plt.figure(figsize=(12, 9))
ax = fig.add_subplot(111)
plt.plot(data.values)
plt.show()

# %% [markdown]
# 2D Scatter plot of multivatiate normal observations

# %%
dv = pd.DataFrame(v,columns=['x1', 'x2']) # convert data to a pandas dataframe
g = sns.jointplot(x="x1", y="x2", data=dv, kind="scatter")
g.set_axis_labels("x_1", "x_2");

# %% [markdown]
# Fancy scatterplot of iris dataset loaded from seaborn as pandas dataframe:

# %%
import matplotlib.pyplot as plt

g = sns.jointplot(x="petal_length", y="petal_width", data=iris, kind="kde", color="m")
g.plot_joint(plt.scatter, c="w", s=30, linewidth=1, marker="+")
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels("petal length", "petal width");

# %% [markdown]
# Scatterplot grouping observations uwing a label:

# %%
fig = plt.figure(figsize=(8,8))
sns.scatterplot(x="sepal_length", y="sepal_width", data=iris,hue="species")
plt.show()

# %% [markdown]
# Swarm plot:

# %%
fig = plt.figure(figsize=(8,8))
sns.swarmplot(x="species", y="petal_length", data=iris)
plt.show()

# %% [markdown]
# Multiple box-plots of a multidimensional dataset:

# %%
fig = plt.figure(figsize=(15,6))
sns.boxplot(x="cylinders", y="mpg", hue="origin",data=dcars, palette="Set3")
plt.show()

# %% [markdown]
# Histogram of the random synthetic data generated above:

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,8))
count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi))*np.exp( - (bins - mu)**2 / (2 * sigma**2) ),linewidth=2, color='r')
plt.show()

# %% [markdown]
# Histogram of a greyscale image:

# %%
import matplotlib.pyplot as plt

# reshape the uint8 image as 1d array:
v = I.flatten()
# Equivalent to:
#v = I.reshape(I.shape[0]*I.shape[1],1)

v = v[v>0]# remove zeros:

fig = plt.figure(figsize=(14, 6))
plt.hist(v, bins=256,density=False)
plt.show()

# %% [markdown]
# ## Basic statistical reports:

# %% [markdown]
# Basic summary statistiscs of a dataset:

# %%
import seaborn as sns
dcars = sns.load_dataset("mpg")
dcars.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
Grouping data and averaging over groups:

# %%
dcars_grouped = dcars.groupby(by=['model_year'])
dcars_grouped.mean()
# Out:
#                   mpg  cylinders  displacement  horsepower       weight  \
# model_year
# 70          17.689655   6.758621    281.413793  147.827586  3372.793103
# 71          21.250000   5.571429    209.750000  107.037037  2995.428571
# 72          18.714286   5.821429    218.375000  120.178571  3237.714286
# 73          17.100000   6.375000    256.875000  130.475000  3419.025000
# 74          22.703704   5.259259    171.740741   94.230769  2877.925926
# 75          20.266667   5.600000    205.533333  101.066667  3176.800000
# 76          21.573529   5.647059    197.794118  101.117647  3078.735294
# 77          23.375000   5.464286    191.392857  105.071429  2997.357143
# 78          24.061111   5.361111    177.805556   99.694444  2861.805556
# 79          25.093103   5.827586    206.689655  101.206897  3055.344828
# 80          33.696552   4.137931    115.827586   77.481481  2436.655172
# 81          30.334483   4.620690    135.310345   81.035714  2522.931034
# ...

# %% [markdown]
# ## Dealing with missing data:

# %%
Copy the iris dataframe and replace some values by NaNs:

# %%
d = sns.load_dataset("iris")
dnans = d;
mask = dnans.petal_length > 1.45
column_name = 'petal_length'
dnans.loc[mask, column_name] = np.nan
dnans.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           NaN          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Filter data avoiding observations affected by NaNs:

# %%
dclean = dnans.loc[dnans['petal_length'].notna()].head()

# %% [markdown]
# Obtain statistical averages avoiding missing observations:

# %%
dclean.mean()
# Out:
# sepal_length    4.86
# sepal_width     3.34
# petal_length    1.38
# petal_width     0.22
# dtype: float64

# %% [markdown]
# Dealing with NaNs - Option 1: Remove observations with a missing value in any of its columns:

# %%
dnans["petal_length"].dropna().head()
# Out:
# 0    1.4
# 1    1.4
# 2    1.3
# 4    1.4
# 6    1.4
# Name: petal_length, dtype: float64

# %% [markdown]
# Dealing with NaNs - Option 2: Replace NaN using the mean:

# %%
dnans_fillmean = dnans.fillna(dnans.mean())
dnans_fillmean.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5         1.400          0.2  setosa
# 1           4.9          3.0         1.400          0.2  setosa
# 2           4.7          3.2         1.300          0.2  setosa
# 3           4.6          3.1         1.325          0.2  setosa
# 4           5.0          3.6         1.400          0.2  setosa

# %% [markdown]
# Dealing with NaNs - Option 3: Replace NaN using the median:

# %%
dnans_fillmedian = dnans.fillna(dnans.median())
dnans_fillmedian.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.4          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Dealing with NaNs - Option 4: Replace NaN using linear interpolation from the neighbouring values:

# %%
dnans_fillint1 = dnans.interpolate()
dnans_fillint1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5          1.40          0.2  setosa
# 1           4.9          3.0          1.40          0.2  setosa
# 2           4.7          3.2          1.30          0.2  setosa
# 3           4.6          3.1          1.35          0.2  setosa
# 4           5.0          3.6          1.40          0.2  setosa

# %% [markdown]
# ## Graphical representation of multidimensional data:

# %% [markdown]
# Pairplot scatter plot of multidimensional data with grouping variable:

# %%
fig = plt.figure(figsize=(14, 14))
sns.pairplot(iris,hue="species")
plt.show()

# %% [markdown]
# # (Multidimensional Scaling, MDS): Low-dimensional projection of high-dimensional data.
#
# This technique projects multidimensional data into a lower dimension space by keeping relative distances between observations. The procedure applies an iterative opitmization scheme in order to obtain the optimal projection function.
#
# - Multidimensional Scaling (MDS) projects high dimensional data to a low-dimensionality space (typically 2D or 3D) {\bf keeping relative distances between observations}.
# - Find a transformation satisfying $d_{ij}^k \approx f(d_{ij}^M)$, where
# $d_{ij}^M$ are pariwise distances between observations $(i,j)$ in the original M-dimensional space and $d_{ij}^k$ are distances in the low k-dimensional space ($k \ll M$).
# - MDS finds the transformation $f$ by minimizing the objective function:
# \begin{equation*}
# S(d_{ij}^k) = \sqrt{\frac{\sum_i \sum_j [f(d_{ij}^M)-d_{ij}^k]^2)]}{\sum_i \sum_j (d_{ij}^k)^2)}}
# \end{equation*}

# %%
import numpy as np
import pylab as py

from sklearn import manifold
from sklearn.metrics import euclidean_distances

seed = np.random.RandomState(seed=3)

# Generate 4d random synthetic data (N variables x M observations):
N = 4
M = 300

M3 = int(round(M/3))
X1 = 10 + 2*np.random.randn(M3,N) # cluster 1 (medium dispersion)
X2 = -10 + 5*np.random.randn(M3,N) # cluster 2 (high dispersion)
X3 = 1*np.random.randn(M3,N) # cluster 3 (low dispersion)

A = np.concatenate((X1,X2,X3))

# Apply MDS algorithm:
mds = manifold.MDS(n_components=2, max_iter=3000, eps=1e-9, random_state=seed,
                   dissimilarity="precomputed", n_jobs=1)
similarities = euclidean_distances(A)
pos = mds.fit(similarities).embedding_

# Represent data in the 2D MDS projection:
fig1 = py.figure()
for i in range(0,M3,1):
    py.scatter(pos[i][0],pos[i][1],marker='o',c='r')
for i in range(M3,2*M3,1):
    py.scatter(pos[i][0],pos[i][1],marker='v',c='g')
for i in range(2*M3,M,1):
    py.scatter(pos[i][0],pos[i][1],marker='x',c='b')
fig1.suptitle('2D MD projection of 4d data')
py.show()

# %% [markdown]
# # Part 2: Dimesionality Reduction using Principal Component Analysis (PCA):

# %% [markdown]
# ### 1.1 PRINCIPAL COMPONENT ANALYSIS (PCA)
# Pytnon implementation (sklearn):
# https://scikit-learn.org/stable/modules/decomposition.html#pca
#
#
#
# Slide3.png![image.png](attachment:image.png)

# %% [markdown]
# Slide4.png![image.png](attachment:image.png)

# %% [markdown]
# Slide5.png![image.png](attachment:image.png)

# %% [markdown]
# Linear coordinate transformation in which the new axis correspond to the directions in which the data presents more dispersion. The procedure is the following:
#
# - $A$: data matrix of size $mxn$ (m observations x n variables).
# - Demean the data: $(A-\bar{A})$.
# - Obtain the $n \times n$ covariance matrix of the data: $C = (A-\bar{A})^T(A-\bar{A})$.
# - Diagonalize C: $C \cdot \vec{v}_i = \lambda_i \vec{v}_i, i = 1,\dots,n$. Eigenvectors $\vec{v}_i$ correspond to the coordinates of the PCA space. Eigenvalues $\lambda_i$ correspond to variance of the original data explained by each component.
# - Variance explained by the principal component $\vec{v}_i$ is: $\frac{\lambda_i}{\sum_i^n\lambda_i}$
# - Project data into the new PCA space. Projection into the ith component: $P_i = A \cdot \vec{v}_i$
#
#
# Slide6.png![image.png](attachment:image.png)

# %% [markdown]
# ## PCA analysis of the iris dataset:

# %%
import seaborn as sns; 

sns.set(style="ticks", color_codes=True)
iris = sns.load_dataset("iris")
g = sns.pairplot(iris, hue="species")

# %% [raw]
# Since we are going to use the sklearn libraries, load the data as numpy array from the sklearn built-in datasets:

# %%
from sklearn import datasets
# %matplotlib inline

iris = datasets.load_iris()
X = iris.data
y = iris.target

# %% [markdown]
# We should standardize the data before proceeding, i.e, subtracting the sample mean and dividing the result by the sample standard deviation:

# %%
XS = (X-X.mean(axis=0))/X.std(axis=0)

# it's equivalent to: 

from sklearn.preprocessing import StandardScaler
XS1 = StandardScaler().fit_transform(X)

# check it:
print('Both ways are equivalent: {}'.format((XS-XS1).sum()))
# Out:
# Both ways are equivalent: 0.0

# %%
import numpy as np
from sklearn import decomposition
from sklearn import datasets
# %matplotlib inline

iris = datasets.load_iris()
X = iris.data
y = iris.target

XS = (X-X.mean(axis=0))/X.std(axis=0)

pca = decomposition.PCA(n_components=4,whiten=False).fit(XS)
Xproj = pca.transform(XS)

# %% [markdown]
# **PCA Eigenvalues and eigenvectors:**

# %%
print('Eigenvalues = {} {} {} {}'.format(*pca.explained_variance_))
print('Eigenvectors = {} {} {} {}'.format(*pca.components_))
# Out:
# Eigenvalues = 2.9380850501999953 0.9201649041624879 0.14774182104494815 0.02085386217646228
# Eigenvectors = [ 0.52106591 -0.26934744  0.5804131   0.56485654] [0.37741762 0.92329566 0.02449161 0.06694199] [-0.71956635  0.24438178  0.14212637  0.63427274] [-0.26128628  0.12350962  0.80144925 -0.52359713]

# %% [markdown]
# Fraction of the variance explained by each Principal component:

# %%
100*pca.explained_variance_ratio_.cumsum()
# same as:
100*pca.explained_variance_.cumsum()/pca.explained_variance_.sum()
# Out:
# array([ 72.96244541,  95.8132072 ,  99.48212909, 100.        ])

# %% [markdown]
# Reproduce results by diagonalization of the data covariance matrix ($d \times d$ dimensions, d: number of features):

# %%
A = np.cov(XS.T)
print(A.shape)
print(A)
# Out:
# (4, 4)
# [[ 1.00671141 -0.11835884  0.87760447  0.82343066]
#  [-0.11835884  1.00671141 -0.43131554 -0.36858315]
#  [ 0.87760447 -0.43131554  1.00671141  0.96932762]
#  [ 0.82343066 -0.36858315  0.96932762  1.00671141]]

# %%
A1 = np.dot(XS.T,XS)/(XS.shape[0]-1)
print(A.shape)
print(A1)
# Out:
# (4, 4)
# [[ 1.00671141 -0.11835884  0.87760447  0.82343066]
#  [-0.11835884  1.00671141 -0.43131554 -0.36858315]
#  [ 0.87760447 -0.43131554  1.00671141  0.96932762]
#  [ 0.82343066 -0.36858315  0.96932762  1.00671141]]

# %%
from numpy import linalg
val,vec = linalg.eig(A)
print('eval = {}'.format(val))
print('evec = {}'.format(vec))

#U,S,Vt = linalg.svd(A)
# Out:
# eval = [2.93808505 0.9201649  0.14774182 0.02085386]
# evec = [[ 0.52106591 -0.37741762 -0.71956635  0.26128628]
#  [-0.26934744 -0.92329566  0.24438178 -0.12350962]
#  [ 0.5804131  -0.02449161  0.14212637 -0.80144925]
#  [ 0.56485654 -0.06694199  0.63427274  0.52359713]]

# %% [markdown]
# Projection of the original 4D data to the 2D PCA space, since the two principal components with largest eigenvalues capture 97% of the variance in the data

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

dfpca = pd.DataFrame(Xproj[:,0:2],columns=['PCA1', 'PCA2'])

fig = plt.figure(figsize=(8,8))

ax = sns.scatterplot(x="PCA1", y="PCA2", hue=y,data=dfpca)
plt.show()

# %% [markdown]
# Represent the directions of the 2 largest eigenvectors:

# %%
# original data (scaled)
dfpcas = pd.DataFrame(XS[:,0:2],columns=['x1', 'x2'])

fig = plt.figure(figsize=(8,8))
sns.scatterplot(x="x1", y="x2", hue=y,data=dfpcas)
plt.arrow(0,0,vec[0][0],vec[0][1],shape='full',fc='r', ec='r', length_includes_head = True, width=0.03)
plt.arrow(0,0,vec[1][0],vec[1][1],shape='full',fc='g', ec='g', length_includes_head = True, width=0.03)
plt.show()

# %% [markdown]
# Check that eigenvectors are indeed orthogonal:

# %%
np.dot(vec[0],vec[1])
# Out:
# -1.1102230246251565e-16

# %% [markdown]
# ## Importance of scaling in PCA:

# %%
from numpy import *
import matplotlib.pyplot as plot
from mpl_toolkits.mplot3d import Axes3D
set_printoptions(precision = 3)

# Datos: distribución normal multivariada en 3d con diferentes std en cada dirección
mean = [1,5,10]
cov = [[2,-1,0],[-1,20,-1],[0,-1,60]]
d = random.multivariate_normal(mean,cov,1000)

# ANALISIS PCA:
# Estandarizacion de los datos ( d1 = (d - d.mean(0))/d.std(0) ):
from sklearn import preprocessing
d1 = preprocessing.scale(d)

# representación gráfica de los datos:
fig = plot.figure(1,figsize=(14, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(d[:,0],d[:,1],d[:,2])
ax.axis('equal')
ax.set_xlabel('X ')
ax.set_ylabel('Y ')
ax.set_zlabel('Z ')
plot.show()

import numpy as np
from sklearn.decomposition import PCA
pca1 = PCA(n_components=3)
pca1.fit(d)
X = pca1.transform(d)
print('PCA without scaling:',format(pca1.explained_variance_ratio_))

pca2 = PCA(n_components=3)
pca2.fit(d1)
X = pca2.transform(d1)
print('PCA with scaling:',format(pca2.explained_variance_ratio_))
# Out:
# PCA without scaling: [0.733 0.243 0.023]
# PCA with scaling: [0.394 0.331 0.275]

# %% [markdown]
# If data is not scaled one of the components will account for much of the variance in the data due to the differences in variable ranges. When data presents different units or scales this is something important to be taken into account.

# %% [markdown]
# ## PCA with artificial data:

# %%
from random import *
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn import decomposition
from sklearn import datasets

plt.close()
# random vectors x1 and x2

mu1, sigma1 = 0, 0.1
mu2, sigma2 = 1, 0.2

x1 = np.random.normal(mu1, sigma1, 10000)
#plt.plot(x1)
#plt.show()
x2 = np.random.normal(mu2, sigma2, 10000)


# creation of x3 and x4
x3 = 0.3*x1+1.2*x2
x4 = 100*x1+0.4*x2

#x4 = np.abs(x1)**0.5+x2  #yes it's exactly the exemple of the statment


# data matrix
M=np.transpose([x1, x2, x3, x4]) #simply creats the matrix
data=pd.DataFrame(data=M) # and now it transforms it into a usefull data matrix

#scatter matrix
sns.pairplot(data)
# PCA analysis
pca = decomposition.PCA(n_components=2)
pca.fit(data)
data_proj = pca.transform(data)
t=pca.explained_variance_ratio_
plt.figure()
plt.title(str("using only the two main eigenvalues \nit represents "+str(1/100*int(10000*(t[0]+t[1])))+"% of the total variance"))
plt.scatter(data_proj[:,0], data_proj[:,1])
plt.show()

# %% [markdown]
# # EXERCISES:
#
# **Exercise 1: Load a UCI database:**
#
# Obtain a multivariate dataset with numerical features for classification problems from the UCI Machine Learning Repository ($n$ observations, $d$ features).
#
# **Exercise 2: Data visualization**
#
# a) Visualize one of the variables using the following representation methods: basic line plot, histogram, boxplot
#
# b) Obtain the summary statistics for the chosen attribute (mean, median, standard deviation, standard error of the mean ($\sigma/\sqrt{n}$), interquartile range, kurtosis, etc).
#
# c) Choose a pair of variables from the data set and visualize the observations using a scatter plot.
#
# d) Use quantile-quantile plot (q-q plot) to visualize if the two previous variables are equally distributed.
#
# e) Visualize all the variables in the data set using a scatter plot matrix. Compute the pairwise linear correlations between variables and represent the results as a correlation plot.
#
# f) Use the class labels of the observations in order to represent the data as a class-grouped scatter plot matrix.
#
# g) Apply Multidimensional Scaling (MDS) in order to project the d-dimensional data in a 2-d space.
#
# **Exercise 3: Dimensionality Reduction with PCA**
#
# a) Select and download a database with **numerical** features from the UCI repository http://archive.ics.uci.edu/ml/.
#
# b) If the database is aimed for classification, make sure to keep only the features and remove the class labels. The resulting matrix should be of size $m \times n$ with $m$ observations and $n$ attributes/variables/features.
#
# c) Plot a scatter correlation plot matrix of the data and visually inspect correlations between attributes. Discuss your observations with your lab mates.
#
# d) Perform a PCA decomposition of the data. Plot the resulting eigenvalues in decreasing order and select how many of them are needed in order to represent a 95\% of the variance in the data.
#
# e) Project and represent the data to the reduced dimensionality PCA space.
