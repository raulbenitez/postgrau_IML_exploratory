# %% [markdown]
# Barcelona Data: Deaths

# %%
#Codigo para permitir importar ficheros de tu pc local 
from google.colab import files
import io
upload=files.upload()
# Out:
#      <input type="file" id="files-add3cf32-702f-49b0-952b-6b0d9bfbbd92" name="files[]" multiple disabled />
#      <output id="result-add3cf32-702f-49b0-952b-6b0d9bfbbd92">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving deaths.csv to deaths.csv

# %%
import pandas as pd
df=pd.read_csv('deaths.csv')
df
# Out:
#       Year  District.Code  ...    Age  Number
# 0     2017              1  ...    0-4       1
# 1     2017              1  ...    0-4       1
# 2     2017              1  ...    0-4       0
# 3     2017              1  ...    0-4       0
# 4     2017              2  ...    0-4       0
# ...    ...            ...  ...    ...     ...
# 4594  2015             10  ...  >=100       1
# 4595  2015             10  ...  >=100       3
# 4596  2015             10  ...  >=100       2
# 4597  2015             10  ...  >=100       1
# 4598  2015             10  ...  >=100       8
#
# [4599 rows x 7 columns]

# %% [markdown]
# 1.-Dimensiones de los datos (número de observaciones, número de variables)

# %%
df.shape
# Out:
# (4599, 7)

# %%
df.columns
# Out:
# Index(['Year', 'District.Code', 'District.Name', 'Neighborhood.Code',
#        'Neighborhood.Name', 'Age', 'Number'],
#       dtype='object')

# %% [markdown]
# 2.-Tipos de variables (numéricas, texto, etc)

# %%
df.dtypes
# Out:
# Year                  int64
# District.Code         int64
# District.Name        object
# Neighborhood.Code     int64
# Neighborhood.Name    object
# Age                  object
# Number                int64
# dtype: object

# %% [markdown]
# 3.-Resumen estadístico básico de las variables numéricas con comentarios sobre valores medios, dispersion, rango y presencia de datos incompletos.

# %%
df.describe()
# Out:
#               Year  District.Code  Neighborhood.Code       Number
# count  4599.000000    4599.000000        4599.000000  4599.000000
# mean   2016.000000       6.246575          37.000000    10.051098
# std       0.816585       2.788639          21.073599    18.559141
# min    2015.000000       1.000000           1.000000     0.000000
# 25%    2015.000000       4.000000          19.000000     0.000000
# 50%    2016.000000       7.000000          37.000000     2.000000
# 75%    2017.000000       8.000000          55.000000    11.000000
# max    2017.000000      10.000000          73.000000   139.000000

# %% [markdown]
# 4.-Obtención de parámetros indicativos mediante filtrado de valores en alguna de las variables

# %%
df.loc[(df['Number']==139)]
# Out:
#       Year  District.Code  ...    Age  Number
# 1249  2017              2  ...  85-89     139
#
# [1 rows x 7 columns]

# %%
df ['Number'].sum()
# Out:
# 46225

# %%
X1=df.loc[(df['Year']==2015)].sum()
X1['Number']
# Out:
# 15478

# %%
X2=df.loc[(df['Year']==2016)].sum()
X2['Number']
# Out:
# 15183

# %%
X3=df.loc[(df['Year']==2017)].sum()
X3['Number']
# Out:
# 15564

# %%
X1['Number']+X2['Number']+X3['Number']
# Out:
# 46225

# %%
x4=df.loc[(df['Year']==2016) & (df['District.Code']==1)].sum()
x4['Number']
# Out:
# 792

# %%
y=df.loc[(df['Year']==2015)].sum()
y['Number']
# Out:
# 15478

# %% [markdown]
# 5.-Representación gráfica de los datos mediante diagramas de barras e histogramas de las variables

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(15,6))
ax = sns.barplot(x="District.Name", y="Number", data=df)
plt.show()
