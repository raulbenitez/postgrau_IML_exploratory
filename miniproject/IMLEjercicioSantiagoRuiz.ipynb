# %% [markdown]
# <a href="https://colab.research.google.com/github/raulbenitez/postgrau_IML_exploratory/blob/master/IMLEjercicioSantiagoRuiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns; 

sns.set(style="ticks", color_codes=True)
mpg = sns.load_dataset("mpg")
mpg_num=mpg.select_dtypes(include='number')
mpg_nnan=mpg_num.dropna()
mpg_nnan.shape
# Out:
# (392, 7)

# %%
mpg_nnan.describe()
# Out:
#               mpg   cylinders  ...  acceleration  model_year
# count  392.000000  392.000000  ...    392.000000  392.000000
# mean    23.445918    5.471939  ...     15.541327   75.979592
# std      7.805007    1.705783  ...      2.758864    3.683737
# min      9.000000    3.000000  ...      8.000000   70.000000
# 25%     17.000000    4.000000  ...     13.775000   73.000000
# 50%     22.750000    4.000000  ...     15.500000   76.000000
# 75%     29.000000    8.000000  ...     17.025000   79.000000
# max     46.600000    8.000000  ...     24.800000   82.000000
#
# [8 rows x 7 columns]

# %%
mpg_nnan.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year'],
#       dtype='object')

# %%
X=mpg_nnan[['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'model_year']]

# %%
from sklearn.preprocessing import StandardScaler
XS = StandardScaler().fit_transform(X)

# %%
from sklearn import decomposition
pca = decomposition.PCA(n_components=3).fit(XS)

# %%
Xproj = pca.transform(XS)
Xproj.shape
# Out:
# (392, 3)

# %%
print('Valores propios = {} {} {} {}'.format(*pca.explained_variance_))
print('Fracción de la varianza explicada = {} {} {} {}'.format(*pca.explained_variance_ratio_))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-61-c8e49a8dae44> in <module>()
# ----> 1 print('Valores propios = {} {} {} {}'.format(*pca.explained_variance_))
#       2 print('Fracción de la varianza explicada = {} {} {} {}'.format(*pca.explained_variance_ratio_))
#
# IndexError: tuple index out of range

# %%
100*pca.explained_variance_ratio_.cumsum()
# Out:
# array([71.58051179, 83.94610315, 94.35172845])

# %%
100*pca.explained_variance_ratio_
# Out:
# array([71.58051179, 12.36559137, 10.4056253 ])

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
d = pd.DataFrame(Xproj)
g = sns.pairplot(d)
