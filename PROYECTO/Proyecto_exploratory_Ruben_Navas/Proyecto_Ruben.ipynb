# %% [markdown]
# <a href="https://colab.research.google.com/github/raulbenitez/postgrau_IML_exploratory/blob/master/PROYECTO/Proyecto_exploratory_Ruben_Navas/Proyecto_Ruben.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Parte 1: Base de datos

# %%
import pandas as pd
import seaborn as sns
paises = pd.read_csv('/content/drive/My Drive/Classroom/19 20_IML Posgrado en Industrial Machine Learning/Proyecto/countries of the world.csv')
paises
# Out:
#              Country                               Region  ...  Industry  Service
# 0       Afghanistan         ASIA (EX. NEAR EAST)           ...      0,24     0,38
# 1           Albania   EASTERN EUROPE                       ...     0,188    0,579
# 2           Algeria   NORTHERN AFRICA                      ...       0,6    0,298
# 3    American Samoa   OCEANIA                              ...       NaN      NaN
# 4           Andorra   WESTERN EUROPE                       ...       NaN      NaN
# ..               ...                                  ...  ...       ...      ...
# 222       West Bank   NEAR EAST                            ...      0,28     0,63
# 223  Western Sahara   NORTHERN AFRICA                      ...       NaN      0,4
# 224           Yemen   NEAR EAST                            ...     0,472    0,393
# 225          Zambia   SUB-SAHARAN AFRICA                   ...      0,29    0,489
# ...

# %%
paises.shape
# Out:
# (227, 20)

# %%
paises.describe()
# Out:
#          Population  Area (sq. mi.)  GDP ($ per capita)
# count  2.270000e+02    2.270000e+02          226.000000
# mean   2.874028e+07    5.982270e+05         9689.823009
# std    1.178913e+08    1.790282e+06        10049.138513
# min    7.026000e+03    2.000000e+00          500.000000
# 25%    4.376240e+05    4.647500e+03         1900.000000
# 50%    4.786994e+06    8.660000e+04         5550.000000
# 75%    1.749777e+07    4.418110e+05        15700.000000
# max    1.313974e+09    1.707520e+07        55100.000000

# %%
paises.dtypes
# Out:
# Country                                object
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)             object
# Coastline (coast/area ratio)           object
# Net migration                          object
# Infant mortality (per 1000 births)     object
# GDP ($ per capita)                    float64
# Literacy (%)                           object
# Phones (per 1000)                      object
# Arable (%)                             object
# Crops (%)                              object
# Other (%)                              object
# Climate                                object
# Birthrate                              object
# Deathrate                              object
# Agriculture                            object
# Industry                               object
# Service                                object
# dtype: object

# %%
paises['Pop. Density (per sq. mi.)'] = pd.to_numeric(paises['Pop. Density (per sq. mi.)'].str.replace(',', '.'))
paises['Coastline (coast/area ratio)'] = pd.to_numeric(paises['Coastline (coast/area ratio)'].str.replace(',', '.'))
paises['Net migration'] = pd.to_numeric(paises['Net migration'].str.replace(',', '.'))
paises['Infant mortality (per 1000 births)'] = pd.to_numeric(paises['Infant mortality (per 1000 births)'].str.replace(',', '.'))
paises['Literacy (%)'] = pd.to_numeric(paises['Literacy (%)'].str.replace(',', '.'))
paises['Phones (per 1000)'] = pd.to_numeric(paises['Phones (per 1000)'].str.replace(',', '.'))
paises['Arable (%)'] = pd.to_numeric(paises['Arable (%)'].str.replace(',', '.'))
paises['Crops (%)'] = pd.to_numeric(paises['Crops (%)'].str.replace(',', '.'))
paises['Other (%)'] = pd.to_numeric(paises['Other (%)'].str.replace(',', '.'))
paises['Climate'] = pd.to_numeric(paises['Climate'].str.replace(',', '.'))
paises['Birthrate'] = pd.to_numeric(paises['Birthrate'].str.replace(',', '.'))
paises['Deathrate'] = pd.to_numeric(paises['Deathrate'].str.replace(',', '.'))
paises['Agriculture'] = pd.to_numeric(paises['Agriculture'].str.replace(',', '.'))
paises['Industry'] = pd.to_numeric(paises['Industry'].str.replace(',', '.'))
paises['Service'] = pd.to_numeric(paises['Service'].str.replace(',', '.'))

paises.astype({'Service': 'float64'}).dtypes
paises.astype({'Industry': 'float64'}).dtypes
paises.astype({'Agriculture': 'float64'}).dtypes
paises.astype({'Deathrate': 'float64'}).dtypes
paises.astype({'Birthrate': 'float64'}).dtypes
paises.astype({'Climate': 'float64'}).dtypes
paises.astype({'Other (%)': 'float64'}).dtypes
paises.astype({'Crops (%)': 'float64'}).dtypes
paises.astype({'Arable (%)': 'float64'}).dtypes
paises.astype({'Phones (per 1000)': 'float64'}).dtypes
paises.astype({'Literacy (%)': 'float64'}).dtypes
paises.astype({'Infant mortality (per 1000 births)': 'float64'}).dtypes
paises.astype({'Net migration': 'float64'}).dtypes
paises.astype({'Pop. Density (per sq. mi.)': 'float64'}).dtypes
paises.astype({'Coastline (coast/area ratio)': 'float64'}).dtypes
# Out:
# Country                                object
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)            float64
# Coastline (coast/area ratio)          float64
# Net migration                         float64
# Infant mortality (per 1000 births)    float64
# GDP ($ per capita)                    float64
# Literacy (%)                          float64
# Phones (per 1000)                     float64
# Arable (%)                            float64
# Crops (%)                             float64
# Other (%)                             float64
# Climate                               float64
# Birthrate                             float64
# Deathrate                             float64
# Agriculture                           float64
# Industry                              float64
# Service                               float64
# dtype: object

# %%
Colum_paises=paises.columns

for kv in Colum_paises:
print(kv)
# Out:
# Country
# Region
# Population
# Area (sq. mi.)
# Pop. Density (per sq. mi.)
# Coastline (coast/area ratio)
# Net migration
# Infant mortality (per 1000 births)
# GDP ($ per capita)
# Literacy (%)
# Phones (per 1000)
# Arable (%)
# Crops (%)
# Other (%)
# Climate
# Birthrate
# Deathrate
# Agriculture
# Industry
# Service

# %%
paises_1=paises.drop(['Arable (%)','Crops (%)','Other (%)'], axis=1)
paises_1
# Out:
#              Country                               Region  ...  Industry  Service
# 0       Afghanistan         ASIA (EX. NEAR EAST)           ...     0.240    0.380
# 1           Albania   EASTERN EUROPE                       ...     0.188    0.579
# 2           Algeria   NORTHERN AFRICA                      ...     0.600    0.298
# 3    American Samoa   OCEANIA                              ...       NaN      NaN
# 4           Andorra   WESTERN EUROPE                       ...       NaN      NaN
# ..               ...                                  ...  ...       ...      ...
# 222       West Bank   NEAR EAST                            ...     0.280    0.630
# 223  Western Sahara   NORTHERN AFRICA                      ...       NaN    0.400
# 224           Yemen   NEAR EAST                            ...     0.472    0.393
# 225          Zambia   SUB-SAHARAN AFRICA                   ...     0.290    0.489
# ...

# %% [markdown]
# ¿El país con mas mortalidad infantil és el que tiene más población?

# %%
Pais_poblacion=paises.loc[(paises['Population']==paises['Population'].max())]
Pais_poblacion['Country']
# Out:
# 42    China
# Name: Country, dtype: object

# %%
Pais_InfMort=paises.loc[(paises['Infant mortality (per 1000 births)']==paises['Infant mortality (per 1000 births)'].min())]
Pais_InfMort['Country']
# Out:
# 184    Singapore
# Name: Country, dtype: object

# %%
Pais_Region=paises.groupby(by=['Region']).mean()
fig = plt.figure(figsize=(10,6))
ax = sns.scatterplot(x="Infant mortality (per 1000 births)", y="Population",hue='Region',data=paises)
plt.show()

# %%
paises_num = paises.select_dtypes(include='number')
paises_num.head()
# Out:
#    Population  Area (sq. mi.)  ...  Industry  Service
# 0    31056997          647500  ...     0.240    0.380
# 1     3581655           28748  ...     0.188    0.579
# 2    32930091         2381740  ...     0.600    0.298
# 3       57794             199  ...       NaN      NaN
# 4       71201             468  ...       NaN      NaN
#
# [5 rows x 18 columns]

# %%
paises.isnull().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
Paises_fillmean = paises.fillna(paises.mean())
Paises_fillmean.isnull().sum()
# Out:
# Country                               0
# Region                                0
# Population                            0
# Area (sq. mi.)                        0
# Pop. Density (per sq. mi.)            0
# Coastline (coast/area ratio)          0
# Net migration                         0
# Infant mortality (per 1000 births)    0
# GDP ($ per capita)                    0
# Literacy (%)                          0
# Phones (per 1000)                     0
# Arable (%)                            0
# Crops (%)                             0
# Other (%)                             0
# Climate                               0
# Birthrate                             0
# Deathrate                             0
# Agriculture                           0
# Industry                              0
# Service                               0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(paises,hue='Region')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
paises['Region'].unique()
# Out:
# array(['ASIA (EX. NEAR EAST)         ',
#        'EASTERN EUROPE                     ',
#        'NORTHERN AFRICA                    ',
#        'OCEANIA                            ',
#        'WESTERN EUROPE                     ',
#        'SUB-SAHARAN AFRICA                 ', 'LATIN AMER. & CARIB    ',
#        'C.W. OF IND. STATES ', 'NEAR EAST                          ',
#        'NORTHERN AMERICA                   ',
#        'BALTICS                            '], dtype=object)
