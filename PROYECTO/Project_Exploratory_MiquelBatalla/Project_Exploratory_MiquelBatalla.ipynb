# %% [markdown]
# <a href="https://colab.research.google.com/github/raulbenitez/postgrau_IML_exploratory/blob/master/PROYECTO/Project_Exploratory_MiquelBatalla/Project_Exploratory_MiquelBatalla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Parte 1: Base de datos

# %%
import pandas as pd
from google.colab import drive
import seaborn as sns
import matplotlib.pyplot as plt

drive.mount('/content/gdrive')
dm = pd.read_csv('/content/gdrive/My Drive/Postgrau IML/Dades Machine Learning/kaggle_diamonds.csv',index_col=0,header=0)
dm.head()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#    carat      cut color clarity  depth  table  price     x     y     z
# 1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
dm.describe()
# Out:
#               carat         depth  ...             y             z
# count  53940.000000  53940.000000  ...  53940.000000  53940.000000
# mean       0.797940     61.749405  ...      5.734526      3.538734
# std        0.474011      1.432621  ...      1.142135      0.705699
# min        0.200000     43.000000  ...      0.000000      0.000000
# 25%        0.400000     61.000000  ...      4.720000      2.910000
# 50%        0.700000     61.800000  ...      5.710000      3.530000
# 75%        1.040000     62.500000  ...      6.540000      4.040000
# max        5.010000     79.000000  ...     58.900000     31.800000
#
# [8 rows x 7 columns]

# %% [markdown]
# Observamos que disponemos de 10 variables, 7 de ellas numéricas, y con 53,940 observaciones sin ausencias (NaNs)

# %%
sns.pairplot(dm,hue='cut')

# %%
dm.groupby(by='cut').mean().sort_values(by=('carat'), ascending=False)
# Out:
#               carat      depth      table  ...         x         y         z
# cut                                        ...
# Fair       1.046137  64.041677  59.053789  ...  6.246894  6.182652  3.982770
# Premium    0.891955  61.264673  58.746095  ...  5.973887  5.944879  3.647124
# Good       0.849185  62.365879  58.694639  ...  5.838785  5.850744  3.639507
# Very Good  0.806381  61.818275  57.956150  ...  5.740696  5.770026  3.559801
# Ideal      0.702837  61.709401  55.951668  ...  5.507451  5.520080  3.401448
#
# [5 rows x 7 columns]

# %%
dm[['cut','carat']].groupby(by='cut').count()
# Out:
#            carat
# cut
# Fair        1610
# Good        4906
# Ideal      21551
# Premium    13791
# Very Good  12082

# %%
dm.set_index(['cut']).count()
# Out:
# carat      53940
# color      53940
# clarity    53940
# depth      53940
# table      53940
# price      53940
# x          53940
# y          53940
# z          53940
# dtype: int64
