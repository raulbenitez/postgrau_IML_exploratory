# %% [markdown]
# <a href="https://colab.research.google.com/github/raulbenitez/postgrau_IML_exploratory/blob/master/MiniPCA_Ton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Ejercicio: Aplicar PCA al dataset mpg (coches)
# -Aplicar PCA
#
# -Qué proporción de la variavilidad de los datos explica cada componente PCA
#
# -Cuantos componentes PCA son necesarios para explicar el 90% de la variabilidad
#
# -Proyectar los datos

# %%
import pandas as pd
import seaborn as sns
mpg = sns.load_dataset("mpg")
mpg_num= mpg.select_dtypes(include='number')
mpg_num.shape
# Out:
# (398, 7)

# %%
mpg.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
XS.shape
# Out:
# (398, 7)

# %%
mpg_nan = mpg_num.dropna()
mpg_nan.shape
# Out:
# (392, 7)

# %%
from sklearn.preprocessing import StandardScaler
XS = StandardScaler().fit_transform(mpg_nan)

# %%
from sklearn import decomposition
pca = decomposition.PCA(n_components=7).fit(XS)

# %%
Xproj = pca.transform(XS)
Xproj.shape
# Out:
# (392, 7)

# %%
print('Valores propios = {} {} {} {}'.format(*pca.explained_variance_))
print('Fracción de la varianza explicada = {} {} {} {}'.format(*pca.explained_variance_ratio_))
# Out:
# Valores propios = 5.023450750382199 0.8678051844996093 0.7302566706735852 0.18438546525537886
# Fracción de la varianza explicada = 0.7158051178569386 0.12365591368052012 0.10405625300049992 0.02627358488150624

# %%
100*pca.explained_variance_ratio_.cumsum()
# Out:
# array([ 71.58051179,  83.94610315,  94.35172845,  96.97908694,
#         98.72074871,  99.49585101, 100.        ])

# %%
XPCA = Xproj[:,0:3]
XPCA.shape
# Out:
# (392, 3)

# %%
d = pd.DataFrame(XPCA,columns=['PCA1','PCA2','PCA3'])
sns.pairplot(d)
plt.show()
